# %%
from langchain_openai import ChatOpenAI
from invoke_agent.agent import InvokeAgent
from dotenv import load_dotenv
import os

load_dotenv()  # This loads variables from the .env file
openai_key = os.getenv("OPENAI_API_KEY")

# Initialize LLM and InvokeExecutor
llm = ChatOpenAI(
    model="gpt-4.5-preview",
    openai_api_key=openai_key,
    #temperature=0.1,  # Balances creativity & coherence
    #max_tokens=5000   # Adjust as needed
)
invoke = InvokeAgent(llm)

# Start interactive loop
print("\n🤖 Invoke Chat Agent is running. Type your request below.")
print("Type 'exit' or 'quit' to stop.\n")

while True:
    user_input = input("📝 You: ").strip()

    if user_input.lower() in ["exit", "quit"]:
        print("\n👋 Exiting Invoke Chat Agent. Goodbye!")
        break  # Exit the loop
    
    print('\n💡 Thinking very hard...')

    final_response = invoke.chat(user_input)
    print(final_response)
# Out:
# 🤖 Invoke Chat Agent is running. Type your request below.
# Type 'exit' or 'quit' to stop.
# 📝 You:  can you find me a mexican restaurant in los gatos and put the details in a calendar event for tomorrow at 8pm?
# 💡 Thinking very hard...
# 🔍 Looking for API key for: googleapis.com
# ✅ Retrieved API key for googleapis.com: AIzaS********
# 🔍 Checking OAuth token for: googleapis.com
# ✅ Token for googleapis.com: ya29.********
# I've created your calendar event for dinner at Zona Rosa, a popular Mexican restaurant in Los Gatos. Here are the details:
#
# - **Restaurant**: Zona Rosa
# - **Address**: 81 W Main St, Los Gatos, CA 95030, United States
# - **Rating**: 4.3 stars
# - **Time**: Tomorrow at 8pm to 10pm (Pacific Time)
#
# You can view the event on your Google Calendar [here](https://www.google.com/calendar/event?eid=MTlvZXM0czBndTI5N210MGQ0ZjR0cHQwc2MgY29vcGVyZG95bGVAbQ).
#
# Enjoy your meal!
