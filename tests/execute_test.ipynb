# %%
from invoke_agent.core import execute_api_call

execute_api_call({
    "action": "GET",
    "url": "https://www.googleapis.com/calendar/v3/calendars/primary/events?q=dinner",
    "auth_code": "oauth::i"
  })
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p337rrle7nu08s0o"',
#  'summary': 'cooper@invoke.network',
#  'description': '',
#  'updated': '2025-06-20T17:12:53.151Z',
#  'timeZone': 'Australia/Sydney',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 10}],
#  'nextSyncToken': 'CM-91ce_gI4DEM-91ce_gI4DGAUgy-fI8AIoy-fI8AI=',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3500879146302878"',
#    'id': 'm6tgak0abv7npudn75j051cngc',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bTZ0Z2FrMGFidjducHVkbjc1ajA1MWNuZ2MgY29vcGVyQGludm9rZS5uZXR3b3Jr',
#    'created': '2025-05-31T10:16:22.000Z',
#    'updated': '2025-06-20T17:12:53.151Z',
#    'summary': 'Dinner at Mamis Bondi',
#    'description': 'Enjoy dinner at Mamis Bondi, a highly rated Mexican restaurant in Bondi.\nAddress: 286 Bondi Rd, Bondi NSW 2026\nRating: 4.8 from 286 reviews.',
#    'location': '286 Bondi Rd, Bondi NSW 2026',
#    'creator': {'email': 'cooper@invoke.network', 'self': True},
#    'organizer': {'email': 'cooper@invoke.network', 'self': True},
#    'start': {'dateTime': '2025-06-01T19:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'end': {'dateTime': '2025-06-01T21:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'iCalUID': 'm6tgak0abv7npudn75j051cngc@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %%
execute_api_call({
    "action": "POST",
    "url": "https://www.googleapis.com/calendar/v3/calendars/primary/events",
    "auth_code": "oauth::i",
    "parameters": {
      "summary": "Dinner with John",
      "start": { "dateTime": "2025-04-15T20:00:00", "timeZone": "Australia/Sydney" },
      "end": { "dateTime": "2025-04-15T22:00:00", "timeZone": "Australia/Sydney" },
      "attendees": [ { "email": "john@example.com" } ]
    }
  })
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p337rrle7nu08s0o"',
#  'summary': 'cooper@invoke.network',
#  'description': '',
#  'updated': '2025-06-20T17:12:53.151Z',
#  'timeZone': 'Australia/Sydney',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 10}],
#  'nextSyncToken': 'CM-91ce_gI4DEM-91ce_gI4DGAUgy-fI8AIoy-fI8AI=',
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3499154738077470"',
#    'id': '00qp7u7immlk0utje0jjn9cpds',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=MDBxcDd1N2ltbWxrMHV0amUwampuOWNwZHMgY29vcGVyQGludm9rZS5uZXR3b3Jr',
#    'created': '2025-06-10T17:42:48.000Z',
#    'updated': '2025-06-10T17:42:49.038Z',
#    'summary': 'Meeting with Alex Ryan',
#    'creator': {'email': 'cooper@invoke.network', 'self': True},
#    'organizer': {'email': 'cooper@invoke.network', 'self': True},
#    'start': {'dateTime': '2025-06-12T14:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'end': {'dateTime': '2025-06-12T15:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'iCalUID': '00qp7u7immlk0utje0jjn9cpds@google.com',
#    'sequence': 0,
#    'attendees': [{'email': 'alex@invoke.network',
#      'responseStatus': 'needsAction'}],
#    'reminders': {'useDefault': True},
#    'eventType': 'default'},
#   {'kind': 'calendar#event',
#    'etag': '"3500879146302878"',
#    'id': 'm6tgak0abv7npudn75j051cngc',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=bTZ0Z2FrMGFidjducHVkbjc1ajA1MWNuZ2MgY29vcGVyQGludm9rZS5uZXR3b3Jr',
#    'created': '2025-05-31T10:16:22.000Z',
#    'updated': '2025-06-20T17:12:53.151Z',
#    'summary': 'Dinner at Mamis Bondi',
#    'description': 'Enjoy dinner at Mamis Bondi, a highly rated Mexican restaurant in Bondi.\nAddress: 286 Bondi Rd, Bondi NSW 2026\nRating: 4.8 from 286 reviews.',
#    'location': '286 Bondi Rd, Bondi NSW 2026',
#    'creator': {'email': 'cooper@invoke.network', 'self': True},
#    'organizer': {'email': 'cooper@invoke.network', 'self': True},
#    'start': {'dateTime': '2025-06-01T19:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'end': {'dateTime': '2025-06-01T21:00:00+10:00',
#     'timeZone': 'Australia/Sydney'},
#    'iCalUID': 'm6tgak0abv7npudn75j051cngc@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %%
from invoke_agent.core import execute_api_call
import base64

raw_email = """To: cooperdoyle@gmail.com
Subject: Hello from API
Content-Type: text/plain; charset="UTF-8"
Content-Transfer-Encoding: 7bit
MIME-Version: 1.0

This is the body of the email."""

# base64url encode (remove padding '=')
encoded = base64.urlsafe_b64encode(raw_email.encode("utf-8")).decode("utf-8").rstrip("=")
print(encoded)

execute_api_call({'action': 'POST',
 'url': 'https://www.googleapis.com/gmail/v1/users/me/messages/send',
 'auth_code': 'oauth::Bearer::i',
 'parameters': {'raw': encoded}
})
# Out:
# VG86IGNvb3BlcmRveWxlQGdtYWlsLmNvbQpTdWJqZWN0OiBIZWxsbyBmcm9tIEFQSQpDb250ZW50LVR5cGU6IHRleHQvcGxhaW47IGNoYXJzZXQ9IlVURi04IgpDb250ZW50LVRyYW5zZmVyLUVuY29kaW5nOiA3Yml0Ck1JTUUtVmVyc2lvbjogMS4wCgpUaGlzIGlzIHRoZSBib2R5IG9mIHRoZSBlbWFpbC4
# {'error': '❌ HTTP 401 -+- 💀 ERR0R: Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.'}

# %%
execute_api_call(
{"action": "POST", "url": "https://www.googleapis.com/gmail/v1/users/me/messages/send", "auth_code": "oauth::Bearer::i", "parameters": {"raw":"..."}}
)
# Out:
# {'id': '19633833f23fd181',
#  'threadId': '19633833f23fd181',
#  'labelIds': ['UNREAD', 'SENT', 'INBOX']}

# %%
from invoke_agent.core import execute_api_call
